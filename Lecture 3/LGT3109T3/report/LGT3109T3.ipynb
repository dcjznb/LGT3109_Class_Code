# %% [markdown]
# # LGT3109 Tutorial 3 Report

# %% [markdown]
#
# #### Input your name and student ID in the cell below (if a cell is not in edit mode, double click it):

# %% [markdown]
# Your name: Dai Cijun
#
# Your student ID: 22102054d

# %% [markdown]
# **Instructions for the report**:
# - Open Anaconda Navigator, and launch Python IDLE through Anaconda Navigation
# - Refer to Section 3.1 of the tutorial book and open tutorial 3 report
# - Follow Section 4 of the tutorial book to save the report and zip the report folder. The zip file is named as LGT3109T3Report{your student_id}.zip (e.g., if student_id is 12345678d, then the zip file's name is LGT3109T3Report12345678d.zip). The zip file needs to include the following files:
#     - an .ipynb file of this tutorial report
#     - image files of flowcharts or screenshots used in this tutorial report
# - Submit the zip file of the report folder in the blackboard. The submission due date is **<font color='red'> 23 Sep 2025 </font>**.

# %% [markdown]
# ### Part 1 Condition Expressions

# %% [markdown]
# #### 1.1. Execute the codes below, and explain meanings of the logic expressions in the if-statement (10 points):

# %% [markdown]
# #### (a)

# %%
company_name = 'FE'
quantity = 200
if (company_name == 'FE' and quantity < 300) or (company_name == 'SF' and quantity < 150):    
    print('The order quantity is too low for carrier', company_name)
# Out:
# The order quantity is too low for carrier FE

# %% [markdown]
# **_Edit this cell to explain the meaning of the expression above:_**
# When the company_name is "FE" and the quantity is less than 300, or the company_name is "SF" and the quantity is less than 150, the if-statement is true, and the print function will be executed.

# %% [markdown]
# #### (b)

# %%
age = 1000
if not (age >= 0 and age <= 150):
    print('The value of age is not valid.')
# Out:
# The value of age is not valid.

# %% [markdown]
# **_Edit this cell to explain the meaning of the expression above:_**
# When the age is not between 0 and 150, the if-not statement is true, and the print function will be executed.

# %% [markdown]
# ### Part 2 Conditional Statements

# %% [markdown]
# #### 2.1. Execute the codes below, and explain meanings of the conditional statements (10 points):

# %% [markdown]
# ##### (a)

# %%
quantity=150
threshold = 80
priority = 0
if quantity < threshold:
    priority = 0
print(priority)
# Out:
# 0

# %% [markdown]
# **_Edit this cell to explain the meaning of the conditional statements above:_**
# For this code, the if statement checks if the quantity is less than the threshold. If true, it would execute the code inside, which is priority = 0. However, in this case, since quantity is 150 and threshold is 80, the condition is false, so the code inside the if block is not executed. The priority remains 0.

# %% [markdown]
# ##### (b)

# %%
quantity=300
threshold = 100
priority = 0
if quantity > 4 * threshold:
    priority = 3
elif quantity > 2 * threshold:
    priority = 2
elif quantity > threshold:
    priority = 1
print(priority)
# Out:
# 2

# %% [markdown]
# **_Edit this cell to explain the meaning of the conditional statements above:_**
# For this code, the quantity is 300, the threshold is 100 and priority is 0, and in the if statement, if quantity > 4 * threshold, priority would be 3, elif quantity > 2 * threshold, priority would be 2, if quantity > threshold, priority would be 1. So according to the value of these numbers, priority should be 2.

# %% [markdown]
# #### 2.2. Execute the code below, explain the errors received, and discuss how to fix the errors (10 points):

# %% [markdown]
# ##### (a)

# %%
quantity=150
product = 'IPhone'
if quantity < 100 Or product != 'IPhone':
    priority = 0
else:
    priority = 1
print(priority)
# Out:
#   Cell In[5], line 3
#     if quantity < 100 Or product != 'IPhone':
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# **_Edit this cell to explain the errors of the code above, and discuss how to fix them:_**
# The error is that "Or" should be "or".

# %% [markdown]
# ##### (b)

# %%
quantity=150
if quantity > 100:
priority = 1
print(priority)
# Out:
#   Cell In[6], line 3
#     priority = 1
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %% [markdown]
# **_Edit this cell to explain the errors of the code above, and discuss how to fix them:_**
# There is no indent before priority, which under the if statement, so it will cause an indentation error. You should add an indent before priority.

# %% [markdown]
# ### Part 3 Flowcharts

# %% [markdown]
# #### 3.1. Write conditional statements for flowcharts below and explain their meanings (30 points)

# %% [markdown]
# ##### (a)

# %% [markdown]
# <img src="T3_flowchart_0.png" width="300">

# %%
#Edit this cell to write conditional statements for the flowchart above:  

location = 'Hong Kong'
if location == 'Hong Kong':
    print('From Hong Kong')
# Out:
# From Hong Kong

# %% [markdown]
# **_Edit this cell to discuss the meaning of the flowchart above:_**
# The flowchart checks if the location is 'Hong Kong'. If true, it prints 'From Hong Kong'. If false, then nothing happens.

# %% [markdown]
# ##### (b)

# %% [markdown]
# <img src="T3_flowchart_1.png" width="500">

# %%
#Edit this cell to write conditional statements for the flowchart above:
location = 'Hong Kong'

if location == 'Hong Kong':
    print('From Hong Kong')
else:
    print('Not from Hong Kong')
# Out:
# From Hong Kong

# %% [markdown]
# **_Edit this cell to discuss the meaning of the flowchart above:_**
# The flowchart checks if the location is 'Hong Kong'. If true, it prints 'From Hong Kong'. If false, it prints 'Not from Hong Kong'.

# %% [markdown]
# ##### (c)

# %% [markdown]
# <img src="T3_flowchart_2.png" width="600">

# %%
#Edit this cell to write conditional statements for the flowchart above:  
location = 'Hong Kong'
age = 21

if location == 'Hong Kong':
    if age >= 20:
        print('pass')
    else:
        print('not pass')
else:
    if age >= 18:
        print('pass')
    else:
        print('not pass')
# Out:
# pass

# %% [markdown]
#  **_Edit this cell to discuss the meaning of the flowchart above:_**
#  The flowchart checks the if the location is Hong Kong and the age according to different situations. If the location is Hong Kong and age is bigger than or equals 20, it prints "pass", else it prints "not pass". If the location is not Hong Kong and the age is bigger than or equals 18, it prints "pass", else it prints "not pass".

# %% [markdown]
# #### 3.2. (Comparing Shipping Quantity). Company FE receives shipping quantities from two business units. Draw a flowchart and write a code to output which business unit has a higher shipping quantity. (10 points)
#
# *Sample Input and Output:*
#
#     Input:
#     Enter the shipping quantity of business unit 1: 10
#     Enter the shipping quantity of business unit 2: 20
#
#     Output:
#     Business unit 2 submits a higher shipping quantity of 20

# %% [markdown]
# **_(1) Edit this cell to insert your flowchart:_**
# <img src="flowchart.png">

# %%
#(2) Edit this cell to write your code:  
quantity_1 = 10
quantity_2 = 20

if quantity_1 > quantity_2:
    print('Business unit 1 submits a higher shipping quantity of', quantity_1)
elif quantity_1 < quantity_2:
    print('Business unit 2 submits a higher shipping quantity of', quantity_2)
else:
    print('Both units submit the same shipping quantity.')
# Out:
# Business unit 2 submits a higher shipping quantity of 20

# %%
quantity_1 = 30
quantity_2 = 20

if quantity_1 > quantity_2:
    print('Business unit 1 submits a higher shipping quantity of', quantity_1)
elif quantity_1 < quantity_2:
    print('Business unit 2 submits a higher shipping quantity of', quantity_2)
else:
    print('Both units submit the same shipping quantity.')
# Out:
# Business unit 1 submits a higher shipping quantity of 30

# %%
quantity_1 = 15
quantity_2 = 15

if quantity_1 > quantity_2:
    print('Business unit 1 submits a higher shipping quantity of', quantity_1)
elif quantity_1 < quantity_2:
    print('Business unit 2 submits a higher shipping quantity of', quantity_2)
else:
    print('Both units submit the same shipping quantity.')
# Out:
# Both units submit the same shipping quantity.

# %% [markdown]
# **_(3) Execute and test your code above for various inputs (at least two diffrent inputs) in IDLE. Edit this cell to insert screenshots of your tests below:_**
#
# <img src= '' width = 500> </img>

# %% [markdown]
# <img src = 'various input screenshot 1.png'>
# <img src = 'various input screenshot2.png'>

# %% [markdown]
# ### Part 5 More Exercises

# %% [markdown]
# #### 5.1. (Comparing Shipping Quantity II). Company FE receives shipping quantities from three business units. Draw a flowchart and write a code to output which business unit has a highest shipping quantity.  (30 points)
#
# *Sample Input and Output:*
#
#     Input:
#     Enter the shipping quantity of business unit 1: 100
#     Enter the shipping quantity of business unit 2: 50
#     Enter the shipping quantity of business unit 3: 150
#
#     Output:
#     Business unit 3 submits the highest shipping quantity of 150

# %% [markdown]
# **_(1) Edit this cell to insert your flowchart:_**
# <img src='Flowchart 2.png'>

# %%
#(2) Edit this cell to write your code:
quantity_1 = 100
quantity_2 = 50
quantity_3 = 150

if quantity_1 >= quantity_2 and quantity_1 >= quantity_3:
    print('Business unit 1 submits the highest shipping quantity of', quantity_1)
elif quantity_2 >= quantity_1 and quantity_2 >= quantity_3:
    print('Business unit 2 submits the highest shipping quantity of', quantity_2)
else:
    print('Business unit 3 submits the highest shipping quantity of', quantity_3)
# Out:
# Business unit 3 submits the highest shipping quantity of 150

# %%
quantity_1 = 50
quantity_2 = 150
quantity_3 = 100

if quantity_1 >= quantity_2 and quantity_1 >= quantity_3:
    print('Business unit 1 submits the highest shipping quantity of', quantity_1)
elif quantity_2 >= quantity_1 and quantity_2 >= quantity_3:
    print('Business unit 2 submits the highest shipping quantity of', quantity_2)
else:
    print('Business unit 3 submits the highest shipping quantity of', quantity_3)
# Out:
# Business unit 2 submits the highest shipping quantity of 150

# %%
quantity_1 = 150
quantity_2 = 100
quantity_3 = 50

if quantity_1 >= quantity_2 and quantity_1 >= quantity_3:
    print('Business unit 1 submits the highest shipping quantity of', quantity_1)
elif quantity_2 >= quantity_1 and quantity_2 >= quantity_3:
    print('Business unit 2 submits the highest shipping quantity of', quantity_2)
else:
    print('Business unit 3 submits the highest shipping quantity of', quantity_3)
# Out:
# Business unit 1 submits the highest shipping quantity of 150

# %% [markdown]
# **_(3) Execute and test your revised code above for various inputs. Edit this cell to copy your test results below:_**
#
# <img src='Screenshot3.png'>
# <img src='Screenshot4.png'>
