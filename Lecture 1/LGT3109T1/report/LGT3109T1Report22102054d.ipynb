# %% [markdown]
# # LGT3109 Tutorial 1 Report

# %% [markdown]
# #### Input your name and student ID in the cell below (<font color='red'>if a cell is not in edit mode, double click it</font>):

# %% [markdown]
# Your name: Dai Cijun
#
# Your student ID: 22102054d

# %% [markdown]
# **Instructions for the report**:
# * Download the tutorial instruction and zip file from Blackboard
# * Open Anaconda Navigator, and launch Python IDLE through Anaconda Navigation.
# * Follow Section 3 of the tutorial instruction and complete the report for Section 3.2 and Section 3.3 below
# * Work on "More Exercises" shown at the end of this report.
# * Follow Section 4 of the tutorial instruction to save the report and zip the report folder. The zip file is named as LGT3109T1Report{your student_id}.zip (e.g., if student_id is 12345678d, then the zip file's name is LGT3109T1Report12345678d.zip). <font color='red'>The zip file needs to include the following files:
#     * an .ipynb file of this tutorial report
#     * an .ipynb file newly created in this tutorial
#     * image files of screenshots captured and used in this tutorial report
#     * words.txt included in the original zip file
#     * hello.py created in this tutorial </font>
# * Section numbers and step numbers below are all referred to those in the tutorial instruction.
# * Submit the zip file of the report folder in Blackboard. The submission due date is **<font color='red'>9 Sep 2025</font>**.

# %% [markdown]
# ### Report for Section 3.2 Open/Rename/Edit/Save/Create Jupyter Notebook

# %% [markdown]
# #### Step 1. See the three types of cells:

# %% [markdown]
# I am a **markdown** cell, add name

# %%
print("I'm a code cell"), run
# Out:
# I'm a code cell
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print("I'm a code cell"), run
#
# NameError: name 'run' is not defined

# %% [raw]
# I am a **raw** cell, edit

# %% [markdown]
# #### Step 2. Rename the notebook title to LGT3109T1Report{student id}, For example, if your student id is 12345678d, then rename the notebook title to LGT3109T1Report12345678d (10 points).

# %% [markdown]
# #### Step 3.e. Type your name to replace "Xiaoyu Wang"  in the following Mark Cell (10 points):

# %% [markdown]
# *In this cell, replace "Xiaoyu Wang" below with your name:*
#
# Dai Cijun

# %% [markdown]
# #### Step 3.f. Change the code in the following Code Cell by replacing "Xiaoyu Wang" with your name (10 points):

# %%
my_name = "Dai Cijun"
print("Hello "+my_name+"!")
# Out:
# Hello Dai Cijun!

# %% [markdown]
# #### Step 4. Execute the code in the above Code Cell (10 points).

# %% [markdown]
# #### Step 5. Save your notebook.

# %% [markdown]
# ### Report for Section 3.3 Edit Screenshot and Insert Pictures in Jupyter Notebook

# %% [markdown]
# #### Follow Steps 1-5 to insert a screenshot of your account information in Windows, in the cell below (20 points):

# %% [markdown]
# <font color='red'>*In this cell, insert the screenshot of your account information:*</font>![Screenshot 1-5.png](./Screenshot%201-5.png)

# %% [markdown]
# ###  More Exercises

# %% [markdown]
# #### 1. Do the following task 1.1 and task 1.2 to make and execute a python code in IDLE (40 points):

# %% [markdown]
# #### 1.1 Refer to instructions in Section 2 to do the followings:
# * Launch a IDLE
# * Create a python file named hello.py
# * Copy the code below to hello.py

# %%
your_name = input("What's your name? ")
your_id = input("What's your student id? ")
greeting_message = "Hello "+your_name+" (id: "+your_id+")!"
print(greeting_message)
# Out:
# Hello  (id: )!

# %% [markdown]
# #### 1.2. Refer to instructions in Section 2 to do the followings:
# * Use IDLE to execute hello.py (when being asked your name, input your name)
# * Take a screenshot to capture the result
# * Insert the screenshot captured in the cell below (see an example screen below, but yours should be different in the name input and shown, and you can double click the picture to select the cell to edit):

# %% [markdown]
# <font color='red'>*In this cell, replace the picture below with your own screenshot:*</font>![Screenshot hellopy.png](./Screenshot%20hellopy.png)

# %% [markdown]
# #### 1.3 In the class, we know that from a system perspective, a code usually consists of three components, including input, process, and output. In the cell below, describe the three components of the code above.

# %% [markdown]
# <font color='red'>*In this cell, describe the three components here:"*</font>
# ### Input: name and student id
# ### Process: transfer the strings that I put into a greeting message
# ### Output: print the greeting message

# %% [markdown]
# #### 2. Refer to the instructions in Section 3.2 to create and edit a new jupyter notebook by doing the followings:
# * Create a new jupyter notebook (see Step 8 of Section 3.2), and
# * In the notebook, create a new cell, and make the cell to be Markdown Cell,
# * In the new cell, write down your name, student ID, and why you choose this subject.
# * <font color='red'>Do not forget to add this newly created jupyter notebook to you tutorial report before your submission on Blackboard!
#
# Take a screenshot of your new jupyter notebook and insert it in the cell below:

# %% [markdown]
# <font color='red'>*In this cell, insert the screenshot of your newly created jupyter notebook:*</font>![Screenshot Myself.png](./Screenshot%20Myself.png)
