# %% [markdown]
# ## Name: Dai Cijun
# ## Student ID: 22102054d
# ### Reason that I joined this class: I have become intrested in IT knowledge since Grade 3, and I've already learned some basic programming skills. I hope to deepen my understanding of IT and gain more practical experience through this course. It would help me do well in future jobs because I sincerely want to join the IT industry and do jobs.
