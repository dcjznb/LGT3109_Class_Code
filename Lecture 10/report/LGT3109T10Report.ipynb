# %% [markdown]
# # LGT3109 Tutorial 10 Report

# %% [markdown]
# #### Input your name and student ID in the cell below (<font color='red'>if a cell is not in edit mode, double click it</font>):

# %% [markdown]
# Your name: Dai Cijun
#
# Your student ID: 22102054d

# %% [markdown]
# #### Objectives:
# - Understand the basic process of acquiring and exploring data
# - Be able to understand and apply the use of ``csv`` package to process CSV  files automatically
# - Be able to understand and apply the use of ``statistics`` package to obtain summary statistics of data
# - Be able to understand and apply the use of ``matlplotlib`` package to draw basic charts for data

# %% [markdown]
# #### **Instructions for the report**:
# * Save the report and zip the report folder, and the zip file is named as LGT3109T11Report{your student_id}.zip (e.g., if student_id is 12345678d, then the zip file's name is LGT3109T11Report12345678d.zip) The zip file needs to include the following files:
#     - an .ipynb file of this tutorial report
#     - image files of screenshots used in this tutorial report
#     - csv files created and generated in this tutorial report
# * Submit the zip file of the report folder in the blackboard. The submission due date is **<font color='red'> 25 November 2025</font>**

# %% [markdown]
# ### Part 1 Acquiring Data

# %% [markdown]
# #### 1.1. Removing the Header from CSV Files

# %% [markdown]
# Say you have the boring job of removing the first line from several hundred CSV files with filenames starting with 'NAICS'. Maybe you’ll be feeding them into an automated process that requires just the data and not the headers at the top of the columns. You could open each file in Excel, delete the first row, and resave the file—but that would take hours. Let’s write a program to do it instead.
#
# The program will need to open every file with the .csv extension and with the filename starting with 'NAICS' in the current working directory, read in the contents of the file, and rewrite the contents without the first row to a file with 'headerRemoved' added to the file name. This will replace the old contents of the CSV file with the new, headless contents.

# %% [markdown]
# ##### Task 1: What is the algorithm to tackle this automation task? What are the data structures needed? How are you going to write the code?

# %% [markdown]
# <font color='red'>Edit this cell to answer the question above. </font>
# Data Structures needed: file_list and data_list.
# 1. Import necessary libraries: os and csv.
# 2. Use os.listdir() to get a list of all files in the current working directory.
# 3. Loop through each file in the directory.
# 4. Check if the file name starts with 'NAICS' and ends with '.csv'.
# 5. If it does, open the file using the csv.reader() method.
# 6. Read the contents of the file and store them in a list.
# 7. Remove the first row from the list.
# 8. Create a new file name by appending 'headerRemoved' to the original file name.
# 9. Open the new file using the csv.writer() method.
# 10. Write the modified list (without the header) to the new file.

# %% [markdown]
# ##### Task 2: Follow the steps below to write the code:

# %% [markdown]
# ##### Step 1: Obtain a list of names of files in the current working directory

# %% [markdown]
# The first thing your program needs to do is to execute the code in the cell below, which uses listdir() method in os module to obtain a list of names of all the files in the current working directory, and stored the list in variable file_names.

# %%
import os
file_names = os.listdir('.')
print(file_names)
# Out:
# ['headerRemovedNAICS_data_2427.csv', 'NAICS_data_3237.csv', 'NAICS_data_7535.csv', 'NAICS_data_7642.csv', 'headerRemovedNAICS_data_7833.csv', 'NAICS_data_8015.csv', 'headerRemovedNAICS_data_2988.csv', 'NAICS_data_3197.csv', 'NAICS_data_7913.csv', 'NAICS_data_4215.csv', 'headerRemovedNAICS_data_4525.csv', 'headerRemovedNAICS_data_2183.csv', 'headerRemovedNAICS_data_9834.csv', 'NAICS_data_1218.csv', 'headerRemovedNAICS_data_6904.csv', 'NAICS_data_4610.csv', 'headerRemovedNAICS_data_7830.csv', 'NAICS_data_1973.csv', 'headerRemovedNAICS_data_2828.csv', 'headerRemovedNAICS_data_3075.csv', 'NAICS_data_1817.csv', 'headerRemovedNAICS_data_9986.csv', 'NAICS_data_9250.csv', 'headerRemovedNAICS_data_5992.csv', 'headerRemovedNAICS_data_9825.csv', 'NAICS_data_8760.csv', 'headerRemovedNAICS_data_1048.csv', 'example.csv', 'headerRemovedNAICS_data_7388.csv', 'NAICS_data_2066.csv', 'headerRemovedNAICS_data_4125.csv', 'NAICS_data_1751.csv', 'headerRemovedNAICS_data_2959.csv', 'NAICS_data_8749.csv', 'headerRemovedNAICS_data_9165.csv', 'headerRemovedNAICS_data_6493.csv', 'headerRemovedNAICS_data_7028.csv', 'NAICS_data_8832.csv', 'NAICS_data_5899.csv', 'NAICS_data_8403.csv', 'NAICS_data_2648.csv', 'headerRemovedNAICS_data_4938.csv', 'headerRemovedNAICS_data_8131.csv', 'headerRemovedNAICS_data_2346.csv', 'NAICS_data_4213.csv', 'NAICS_data_1814.csv', 'NAICS_data_3144.csv', 'NAICS_data_5092.csv', 'headerRemovedNAICS_data_8085.csv', 'headerRemovedNAICS_data_8522.csv', 'NAICS_data_6161.csv', 'headerRemovedNAICS_data_7765.csv', 'headerRemovedNAICS_data_9012.csv', 'headerRemovedNAICS_data_6335.csv', 'headerRemovedNAICS_data_3073.csv', 'headerRemovedNAICS_data_5364.csv', 'NAICS_data_5631.csv', 'headerRemovedNAICS_data_8196.csv', 'NAICS_data_5341.csv', 'headerRemovedNAICS_data_8545.csv', 'headerRemovedNAICS_data_7138.csv', 'headerRemovedNAICS_data_7845.csv', 'NAICS_data_6700.csv', 'NAICS_data_2994.csv', 'NAICS_data_4329.csv', 'headerRemovedNAICS_data_7677.csv', 'headerRemovedNAICS_data_5060.csv', 'NAICS_data_3731.csv', 'rates1.csv', 'NAICS_data_8499.csv', 'headerRemovedNAICS_data_6637.csv', 'rates3.csv', 'headerRemovedNAICS_data_8397.csv', 'NAICS_data_4699.csv', 'NAICS_data_4896.csv', 'headerRemovedNAICS_data_4618.csv', 'headerRemovedNAICS_data_1952.csv', 'headerRemovedNAICS_data_7338.csv', 'NAICS_data_2799.csv', 'headerRemovedNAICS_data_9103.csv', 'NAICS_data_7226.csv', 'NAICS_data_1657.csv', 'rates2.csv', 'headerRemovedNAICS_data_5305.csv', 'headerRemovedNAICS_data_6181.csv', 'headerRemovedNAICS_data_6397.csv', 'NAICS_data_3044.csv', 'headerRemovedNAICS_data_7102.csv', 'NAICS_data_2993.csv', 'headerRemovedNAICS_data_4436.csv', 'headerRemovedNAICS_data_9066.csv', 'headerRemovedNAICS_data_5890.csv', 'NAICS_data_6329.csv', 'NAICS_data_6842.csv', 'headerRemovedNAICS_data_2092.csv', 'NAICS_data_8700.csv', 'NAICS_data_7427.csv', 'NAICS_data_3494.csv', 'headerRemovedNAICS_data_9448.csv', 'NAICS_data_3495.csv', 'NAICS_data_7383.csv', 'headerRemovedNAICS_data_9139.csv', 'NAICS_data_1889.csv', 'headerRemovedNAICS_data_4031.csv', 'headerRemovedNAICS_data_7535.csv', 'headerRemovedNAICS_data_3237.csv', 'NAICS_data_2427.csv', 'NAICS_data_2988.csv', 'headerRemovedNAICS_data_3197.csv', 'NAICS_data_7833.csv', 'headerRemovedNAICS_data_8015.csv', 'headerRemovedNAICS_data_7642.csv', 'LGT3109T10Report.ipynb', 'NAICS_data_2183.csv', 'NAICS_data_4525.csv', 'headerRemovedNAICS_data_4215.csv', 'headerRemovedNAICS_data_7913.csv', 'NAICS_data_9834.csv', 'headerRemovedNAICS_data_1973.csv', 'NAICS_data_7830.csv', 'headerRemovedNAICS_data_4610.csv', 'headerRemovedNAICS_data_1218.csv', 'NAICS_data_6904.csv', 'NAICS_data_3075.csv', 'NAICS_data_2828.csv', 'headerRemovedNAICS_data_9250.csv', 'headerRemovedNAICS_data_1817.csv', 'NAICS_data_9986.csv', 'NAICS_data_7388.csv', 'NAICS_data_1048.csv', 'headerRemovedNAICS_data_8760.csv', 'NAICS_data_9825.csv', 'NAICS_data_5992.csv', 'NAICS_data_9165.csv', 'headerRemovedNAICS_data_1751.csv', 'headerRemovedNAICS_data_8749.csv', 'NAICS_data_2959.cs ...

# %% [markdown]
# ##### Step 2: Loop Through Each CSV File and Edit It

# %% [markdown]
# In the code below, write a for loop through each file name in file_names, if the file name starts with 'NAICS' and ends with ".csv", do the followings:
# - (1) Create an empty list named csvRows to store rows beyond the first row of the CSV file
# - (2) Create a CSV reader object
# - (3) Write a for loop to read each row of the CSV file, and for each row, if it is not the first row, append it to the list csvRows
# - (4) create a CSV writer object for a new CSV file with its file name equal to 'headerRemoved'+file_name
# - (5) Write a for loop to write each row in csvRows to the new csv file
# - (6) Close the new CSV file and the oririnal CSV file

# %%
#Edit this cell for Step 2
import csv

for file_name in file_names:
    if file_name.startswith ('NAICS') and file_name.endswith('.csv'):
        print(file_name)        
        #(1) Create an empty list named csvRows to store rows beyond the first row of the CSV file
        csvRows = []
        #(2) Create a CSV reader object named csv_reader
        with open(file_name, mode='r', newline='', encoding='utf-8') as csvfile:
            csv_reader = csv.reader(csvfile)
        #(3) Write a for loop to read each row of the CSV file, and for each row, if it is not the first row, 
        #append it to the list csvRows        
            for index, row in enumerate(csv_reader):
                if index != 0:
                    csvRows.append(row)
        #(4) create a CSV writer object for a new CSV file with its file name equal to 'headerRemoved'+file_name
        with open('headerRemoved'+file_name, mode='w', newline='', encoding='utf-8') as csvfile:
            csv_writer = csv.writer(csvfile)
        
        #(5) Write a for loop to write each row in csvRows to the new csv file
            for row in csvRows:
                csv_writer.writerow(row)

        #(6) Close the new CSV file and the original CSV file
        csvfile.close()
# Out:
# NAICS_data_3237.csv
# NAICS_data_7535.csv
# NAICS_data_7642.csv
# NAICS_data_8015.csv
# NAICS_data_3197.csv
# NAICS_data_7913.csv
# NAICS_data_4215.csv
# NAICS_data_1218.csv
# NAICS_data_4610.csv
# NAICS_data_1973.csv
# NAICS_data_1817.csv
# NAICS_data_9250.csv
# NAICS_data_8760.csv
# NAICS_data_2066.csv
# NAICS_data_1751.csv
# NAICS_data_8749.csv
# NAICS_data_8832.csv
# NAICS_data_5899.csv
# NAICS_data_8403.csv
# NAICS_data_2648.csv
# NAICS_data_4213.csv
# NAICS_data_1814.csv
# NAICS_data_3144.csv
# NAICS_data_5092.csv
# NAICS_data_6161.csv
# NAICS_data_5631.csv
# NAICS_data_5341.csv
# NAICS_data_6700.csv
# NAICS_data_2994.csv
# NAICS_data_4329.csv
# NAICS_data_3731.csv
# NAICS_data_8499.csv
# NAICS_data_4699.csv
# NAICS_data_4896.csv
# NAICS_data_2799.csv
# NAICS_data_7226.csv
# NAICS_data_1657.csv
# NAICS_data_3044.csv
# NAICS_data_2993.csv
# NAICS_data_6329.csv
# NAICS_data_6842.csv
# NAICS_data_8700.csv
# NAICS_data_7427.csv
# NAICS_data_3494.csv
# NAICS_data_3495.csv
# NAICS_data_7383.csv
# NAICS_data_1889.csv
# NAICS_data_2427.csv
# NAICS_data_2988.csv
# NAICS_data_7833.csv
# NAICS_data_2183.csv
# NAICS_data_4525.csv
# NAICS_data_9834.csv
# NAICS_data_7830.csv
# NAICS_data_6904.csv
# NAICS_data_3075.csv
# NAICS_data_2828.csv
# NAICS_data_9986.csv
# NAICS_data_7388.csv
# NAICS_data_1048.csv
# NAICS_data_9825.csv
# NAICS_data_5992.csv
# NAICS_data_9165.csv
# NAICS_data_2959.csv
# NAICS_data_4125.csv
# NAICS_data_8131.csv
# NAICS_data_2346.csv
# NAICS_data_4938.csv
# NAICS_data_7028.csv
# NAICS_data_6493.csv
# NAICS_data_8522.csv
# NAICS_data_8085.csv
# NAICS_data_5364.csv
# NAICS_data_3073.csv
# NAICS_data_7765.csv
# NAICS_data_6335.csv
# NAICS_data_9012.csv
# NAICS_data_8196.csv
# NAICS_data_7845.csv
# NAICS_data_8545.csv
# NAICS_data_7138.csv
# NAICS_data_7677.csv
# NAICS_data_5060.csv
# NAICS_data_6637.csv
# NAICS_data_8397.csv
# NAICS_data_4618.csv
# NAICS_data_9103.csv
# NAICS_data_7338.csv
# NAICS_data_1952.csv
# NAICS_data_6397.csv
# NAICS_data_6181.csv
# NAICS_data_5305.csv
# NAICS_data_7102.csv
# NAICS_data_4436.csv
# NAICS_data_5890.csv
# NAICS_data_9066.csv
# NAICS_data_9448.csv
# NAICS_data_2092.csv
# NAICS_data_9139.csv
# NAICS_data_4031.csv

# %% [markdown]
# ##### Task 3: Test the above codes, and paste the screenshots of any two newly created files in the cell below:

# %% [markdown]
# <font color='red'>Edit this cell to illustrate the testing results, and paste the screenshots of any two newly created files. </font>
# After running the code, new files were successfully created in the current directory, the name being 'headerRemoved'+file_name. Below are the screenshots of the contents of any two newly created files:
# <img src="file 1.png" width="600">
# <img src="file 2.png" width="600">

# %% [markdown]
# ### Part 2 Exploring Data

# %% [markdown]
# #### 2.1. Write codes for the following tasks:

# %% [markdown]
# #####  Task 1. Given a list y = [5.4, 8.0, 1.0, 6.3, 2.9, 7.4, 7.9, 9.8, 4.9, 7.4], write a code in the cell below to print the sum, the max value, the min value, the mean value, and the standard deviation of the list.

# %%
#edit code for task 1
import statistics
y = [5.4, 8.0, 1.0, 6.3, 2.9, 7.4, 7.9, 9.8, 4.9, 7.4]
print("Sum:", sum(y))
print("Max:", max(y))
print("Min:", min(y))
print("Mean:", statistics.mean(y))
print("Standard Deviation:", statistics.stdev(y))
# Out:
# Sum: 61.0
# Max: 9.8
# Min: 1.0
# Mean: 6.1000000000000005
# Standard Deviation: 2.627630956668848

# %% [markdown]
# ##### Task 2. Given a list y = [5.4, 8.0, 1.0, 6.3, 2.9, 7.4, 7.9, 9.8, 4.9, 7.4], write a code to plot it in a bar chart.

# %%
#edit code for task 2
import matplotlib.pyplot as plt
y = [5.4, 8.0, 1.0, 6.3, 2.9, 7.4, 7.9, 9.8, 4.9, 7.4]
plt.bar(range(len(y)), y)
plt.show()

# %% [markdown]
# ##### Task 4. Given two list y1 = [5.4, 8.0, 1.0, 6.3, 2.9, 7.4, 7.9, 9.8, 4.9, 7.4] and y2 = [5.49, 7.58, 1.5, 6.74, 3.33, 7.17, 7.53, 10.18, 4.63, 6.91], write a code to plot it in a scatterplot.

# %%
#edit code for task 1
import matplotlib.pyplot as plt
y1 = [5.4, 8.0, 1.0, 6.3, 2.9, 7.4, 7.9, 9.8, 4.9, 7.4]
y2 = [5.49, 7.58, 1.5, 6.74, 3.33, 7.17, 7.53, 10.18, 4.63, 6.91]
plt.scatter(y1, y2)
plt.show()
